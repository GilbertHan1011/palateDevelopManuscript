# %% [markdown]
# Here, I combine direct and extend eRegulon for input of CellOracle

# %%
import pandas as pd

# %%
directReg = pd.read_csv("../process/20241226_scenicplus_outs/eRegulon_direct.tsv",sep="\t")

# %%
#directPos = directReg[directReg["regulation"] == 1]

# %%
extendReg = pd.read_csv("../process/20241226_scenicplus_outs/eRegulons_extended.tsv",sep="\t")

# %%
#extendRegPos = extendReg[extendReg["regulation"] == 1]

# %%
regNet = pd.concat([directReg,extendReg],axis=0)

# %%
regNetDict = regNet[["Gene","TF"]]

# %%
regNetDict.to_csv("../process/20241226_scenicplus_outs/20250107_tf2gene.csv")
