# %%
import scanpy as sc
import pandas as pd

# %%
adata = sc.read("../../2024.4_scATAC/data/palate_epi_MAGIC_periderm_MAGIC_harmony_renamed.h5ad")

# %%
adata.raw = adata

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 19404 × 23143
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'group', 'SCT_snn_res.0.6', 'celltype', 'SCT_snn_res.0.4', 'S.Score', 'G2M.Score', 'Phase', 'old.ident', 'ident'
#     uns: 'X_name', 'log1p'
#     obsm: 'HARMONY', 'PCA', 'UMAP'
#     layers: 'logcounts'

# %%
label = pd.read_csv("../../2024.4_scATAC/processed_data/cluster/rna_annotation_scvi_mod.csv")

# %%
adata.obs["knn_label"]
# Out:
# E125_1_AAACCCAAGTCATGAA-1    stem cells
# E125_1_AAACCCACAAGACCGA-1    stem cells
# E125_1_AAACCCACATGCACTA-1       Transit
# E125_1_AAACCCAGTCAGTCGC-1    stem cells
# E125_1_AAACCCAGTCCACGCA-1    stem cells
#                                 ...
# E145_2_TTTGGTTCATACCATG-1         K5(-)
# E145_2_TTTGGTTCATGCCGGT-1         K5(-)
# E145_2_TTTGGTTTCGTAGGAG-1       Transit
# E145_2_TTTGTTGCACACCGAC-1       Transit
# E145_2_TTTGTTGTCAACTGGT-1       Transit
# Name: knn_label, Length: 19404, dtype: object

# %%
adata.obs["knn_label"] = label["level1_anno"].values

# %%
adata.write_h5ad("../process/framework/obj/20241220_scenicplus_prepare_rna.h5ad")

# %%
label
# Out:
#                       Unnamed: 0 level1_anno level2_anno
# 0      E125_1_AAACCCAAGTCATGAA-1  stem cells       stem1
# 1      E125_1_AAACCCACAAGACCGA-1  stem cells       stem1
# 2      E125_1_AAACCCACATGCACTA-1     Transit   Transit 4
# 3      E125_1_AAACCCAGTCAGTCGC-1  stem cells       stem2
# 4      E125_1_AAACCCAGTCCACGCA-1  stem cells       stem1
# ...                          ...         ...         ...
# 19399  E145_2_TTTGGTTCATACCATG-1       K5(-)       K5(-)
# 19400  E145_2_TTTGGTTCATGCCGGT-1       K5(-)       K5(-)
# 19401  E145_2_TTTGGTTTCGTAGGAG-1     Transit   Transit 2
# 19402  E145_2_TTTGTTGCACACCGAC-1     Transit   Transit 2
# 19403  E145_2_TTTGTTGTCAACTGGT-1     Transit   Transit 1
#
# [19404 rows x 3 columns]
