# %%
# !scenicplus init_snakemake --out_dir 20241219_scenic_pipeline
# Out:
# 2024-12-19 17:15:08,019 SCENIC+      INFO     Creating snakemake folder in: 20241219_scenic_pipeline

# %%
# !tree 20241219_scenic_pipeline/
# Out:
# 20241219_scenic_pipeline/
# └── Snakemake
#     ├── config
#     │   └── config.yaml
#     └── workflow
#         └── Snakefile
#
# 3 directories, 2 files

# %%
# !mkdir -p ../process/20241219_scenicplus_outs
# !mkdir -p ../../../tmp
