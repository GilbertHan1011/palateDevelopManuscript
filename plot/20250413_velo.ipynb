# %%
import numpy as np

import cellrank as cr
import scanpy as sc
import scvelo as scv
import pandas as pd

# %%
adata = sc.read("../../../2024.4_scATAC//processed_data/framework/velocity/merge_velo.h5ad")
# Out:
# /home/zhanglab/micromamba/envs/py311/lib/python3.11/site-packages/anndata/compat/__init__.py:311: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /home/zhanglab/micromamba/envs/py311/lib/python3.11/site-packages/anndata/compat/__init__.py:311: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(

# %%
scv.settings.figdir = "../../descriptive_results/rna_trajecotry/"

# %%
adata = sc.read("../../../2024.4_scATAC/processed_data/framework/velocity/20241005_merge_paga.h5ad")

# %%
color_dict_line = {
    'K5(-)': '#F2C9D5',
    'K6+ cells': '#B43E44',
    'K14(-)': '#282828',
    'Mature K5(-) ': '#8B6D9C',
    'Shh(+)': '#496496',
    'Transit': '#FADF92',
    'stem cells': '#904869'}

# %%
scv.pl.paga(adata, basis='umap', size=50, alpha=.1,
            min_edge_width=2, node_size_scale=1.5,palette=color_dict_line,save="_scvelo.pdf")
# Out:
# WARNING: Invalid color key. Using grey instead.
# saving figure to file ../../descriptive_results/rna_trajecotry/scvelo__scvelo.pdf

# %%
scv.pl.paga(adata, basis='umap', size=50, alpha=.1,
            min_edge_width=2, node_size_scale=1.5)
# Out:
# WARNING: Invalid color key. Using grey instead.
